# %%
# 🌟 Exercice 1 : Hello World
# Affiche "Hello world" quatre fois sur une seule ligne.
print("Hello world\nHello world\nHello world\nHello world")


# 🌟 Exercice 2 : Some Math
# Calcule (99^3) * 8, c'est-à-dire 99 à la puissance 3, multiplié par 8.
resultat = (99 ** 3) * 8
print(resultat)


# 🌟 Exercice 3 : Quel est ton nom ?
# Demande à l'utilisateur son nom et compare avec le mien, puis affiche un message amusant.
mon_nom = "Alice"  # Par exemple, mon nom est Alice
nom_utilisateur = input("Quel est ton nom ? ")

if nom_utilisateur == mon_nom:
    print("Wow, on a le même nom ! C'est la classe !")
else:
    print(f"Ton nom est {nom_utilisateur}, mais moi c'est {mon_nom}.")


# 🌟 Exercice 4 : As-tu la taille pour faire un roller coaster ?
# Demande la taille en cm et affiche un message selon la taille.
taille = int(input("Quelle est ta taille en centimètres ? "))

if taille > 145:
    print("Tu es assez grand(e) pour faire un tour de montagnes russes !")
else:
    print("Tu dois encore grandir un peu pour faire un tour de montagnes russes.")


# 🌟 Exercice 5 : Numéros favoris
# Travaillons avec des sets.
my_fav_numbers = {3, 7, 21}  # Mes numéros préférés
# Ajoutons deux nouveaux numéros
my_fav_numbers.add(42)
my_fav_numbers.add(99)

# Supprimer le dernier numéro ajouté (le dernier qui a été ajouté n'a pas d'ordre, mais on peut supprimer un spécifique)
# Par exemple, supprimer 99
my_fav_numbers.remove(99)

# Créer un set pour les numéros préférés de mon ami
friend_fav_numbers = {7, 11, 42}

# Concaténer (unionner) les deux sets pour créer un nouveau set
our_fav_numbers = my_fav_numbers.union(friend_fav_numbers)

print("Nos numéros préférés : ", our_fav_numbers)


# 🌟 Exercice 6 : Tuple
# Les tuples sont immuables, on ne peut pas y ajouter directement.
mon_tuple = (1, 2, 3)

# Essayer d'ajouter un élément provoquera une erreur
# On peut, par contre, créer un nouveau tuple en concaténant
nouveau_tuple = mon_tuple + (4,)
print("Tuple initial :", mon_tuple)
print("Nouveau tuple :", nouveau_tuple)


# 🌟 Exercice 7 : Manipulation de listes
basket = ["Banana", "Apples", "Oranges", "Blueberries"]

# Supprimer "Banana"
basket.remove("Banana")
# Supprimer "Blueberries"
basket.remove("Blueberries")
# Ajouter "Kiwi" à la fin
basket.append("Kiwi")
# Ajouter "Apples" au début
basket.insert(0, "Apples")
# Compter combien de fois "Apples" apparaît
nombre_apples = basket.count("Apples")
print("Nombre de 'Apples' dans la liste :", nombre_apples)
# Vider la liste
basket.clear()
# Afficher la liste finale
print("Liste finale :", basket)


# 🌟 Exercice 8 : Commandes de sandwich
sandwich_orders = ["Tuna sandwich", "Pastrami sandwich", "Avocado sandwich", "Pastrami sandwich", "Egg sandwich", "Chicken sandwich", "Pastrami sandwich"]
# Enlever toutes les occurrences de "Pastrami sandwich"
while "Pastrami sandwich" in sandwich_orders:
    sandwich_orders.remove("Pastrami sandwich")

# Liste pour les sandwiches préparés
finished_sandwiches = []

# Préparer chaque sandwich
while sandwich_orders:
    current_sandwich = sandwich_orders.pop(0)  # retire le premier de la liste
    finished_sandwiches.append(current_sandwich)  # l'ajoute à la liste terminée

# Afficher ce qui a été préparé
for sandwich in finished_sandwiches:
    print(f"J'ai préparé votre {sandwich.lower()}")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# 7762392
# Quel est ton nom ? Bernard
# Ton nom est Bernard, mais moi c'est Alice.
# Quelle est ta taille en centimètres ? 171
# Tu es assez grand(e) pour faire un tour de montagnes russes !
# Nos numéros préférés :  {3, 21, 7, 42, 11}
# Tuple initial : (1, 2, 3)
# Nouveau tuple : (1, 2, 3, 4)
# Nombre de 'Apples' dans la liste : 2
# Liste finale : []
# J'ai préparé votre tuna sandwich
# J'ai préparé votre avocado sandwich
# J'ai préparé votre egg sandwich
# J'ai préparé votre chicken sandwich
